# %%
#make heterostructure
#%%
#Import a lot of stuff
import numpy as np
import matplotlib.pyplot as plt
from qeh import make_heterostructure, Heterostructure
from default_parameters import get_thickness, get_intermass
import ase.units

Hartree = ase.units.Hartree#Hartree energy
Bohr = ase.units.Bohr#Bohr radius

# Choose number of padding layers.
# Can experiment with and without encapsulating (padding) in BN
nPadding=3
#material list
material_List=['H-MoS2','H-MoSe2','H-MoTe2','H-WS2','H-WSe2']
#material_List=['H-MoS2','H-MoSe2','H-MoTe2']
n_materials=len(material_List)
range_materials=range(n_materials)
binding_Energies_Mat=np.zeros((n_materials,n_materials))
index_Vec=[(ie,jh) for ie in range_materials for jh in range_materials]
W_Exciton_Matrix=[[]]*n_materials**2
count=-1
#print(binding_Energies_Mat)
for ie in range_materials:
    for jh in range_materials:
        count+=1
        #Choose ndoped material and pdoped
        e_layer_formula=material_List[ie]
        h_layer_formula=material_List[jh]
        #layer thicknesses from the middle of one layer to another
        d_BN = get_thickness('BN')  # hBN-hBN distance#3.22 før
        d_MoS2 = get_thickness(e_layer_formula)
        d_MoS2_BN = (d_BN+d_MoS2)/2  # MoS2-hBN distance
        d_WSe2 = get_thickness(h_layer_formula)
        d_WSe2_BN = (d_BN+d_WSe2)/2  # WSe2-hBN distance
        #list of layer thicknesses
        d= [d_BN]*(nPadding-1) + [d_MoS2_BN]*2 + [d_BN]*(3-1) + [d_WSe2_BN]*2 + [d_BN]*(nPadding-1)
        #layers
        layers = ['{}BN'.format(nPadding), e_layer_formula, '3BN', h_layer_formula, '{}BN'.format(nPadding)]

        # hs = make_heterostructure(layers) #could be used. We choose to input some parameters ourselves to get a feeling for what is going on
        hs = Heterostructure(structure=layers,  # set up structure
                                d=d,                         # layer distance array
                                include_dipole=True,
                                wmax=0,                      # only include \omega=0
                                qmax=1,                      # q grid up to 1 Ang^{-1}
                                d0=0)                     # width of single layer (only used for monolayer calculation), so currently set to 0
        # %%
        # # Get Macroscropic Dielectric function - this is a test that things look reasonable
        q, w, epsM = hs.get_macroscopic_dielectric_function()
        # # plot
        plt.plot(q, epsM.real)
        plt.xlim(0, 1)
        plt.xlabel(r'$q_\parallel (\mathrm{\AA^{-1}}$)', fontsize=20)
        plt.ylabel(r'$\epsilon_M(q, \omega=0)$', fontsize=20)
        plt.title('Static dielectric function', fontsize=20)
        plt.savefig('./plots/eps_vdWH_{}_{}_{}Padding.svg'.format(e_layer_formula[2:],h_layer_formula[2:],nPadding))
        plt.close()
        # plt.show()

        # %%
        # Calculate screened potential W(q, \omega)
        W_MoS2 = hs.get_screened_potential(layer=nPadding)
        W_WSe2 = hs.get_screened_potential(layer=nPadding+4)
        q = hs.q_abs / Bohr # get q-array (momentum transfer range) in Ångstrom.
        indexQ_start=4
        # plot together
        plt.plot(q[indexQ_start:], W_MoS2[indexQ_start:,].real)
        plt.plot(q[indexQ_start:], W_WSe2[indexQ_start:,].real,'--')
        # plt.xlim(0, 1)
        plt.xlabel(r'$q_\parallel (\mathrm{\AA^{-1}}$)', fontsize=20)
        plt.ylabel(r'$U}(q, \omega=0)$', fontsize=20)
        plt.title('Screened potential', fontsize=20)
        plt.legend([e_layer_formula[2:],h_layer_formula[2:]], fontsize=20)
        plt.savefig('./plots/VScr_vdWH_{}_{}_{}.svg'.format(e_layer_formula[2:],h_layer_formula[2:],nPadding))
        plt.show()
        plt.close()

        # %%
        # Plot exciton screened potential
        # 2*number of layers, first is spin up
        # but no electrons in BN-layers
        # consider single electron in n-doped layer
        # consider single hole in p-dopedlayer
        zeroPadding=np.zeros(2*nPadding)
        hl_array = np.hstack([zeroPadding, np.array([1., 0.]), np.zeros(6), np.array([0., 0.]),zeroPadding ])
        el_array = np.hstack([zeroPadding, np.array([0., 0.]), np.zeros(6), np.array([1., 0.]),zeroPadding ])

        # Calculate exciton screened 
        _,W_Exciton,_ = hs.get_exciton_screened_potential(e_distr=el_array, h_distr=hl_array)
        print(W_Exciton)
        #plot
        plt.plot(q[indexQ_start:], W_Exciton[indexQ_start:].real)
        # plt.xlim(0, 1)
        plt.xlabel(r'$q_\parallel (\mathrm{\AA^{-1}}$)', fontsize=20)
        plt.ylabel(r'$W(q, \omega=0)$', fontsize=20)
        plt.title('Screened exciton potential', fontsize=20)
        plt.savefig('./plots/VScr_Exciton_vdWH_{}_{}_{}.svg'.format(e_layer_formula[2:],h_layer_formula[2:],nPadding))
        plt.show()
        W_Exciton_Matrix[count]=W_Exciton
        #exciton binding energies
        # The effective interlayer exciton mass is calculated as:
        # 1/m*=1/me*+1/mh*.
        # me* and mh* can be found in c2db,
        # but we import them from the default_parameters.py.
        ee, ev = hs.get_exciton_binding_energies(eff_mass=get_intermass('H-WSe2', 'H-MoS2'),
                                                 e_distr=el_array,
                                                 h_distr=hl_array)

        print('The interlayer exciton binding energy is: {:0.4f} eV'.format(-ee[0].real))
        print('The (first 5) interlayer exciton binding energies are:'.format(-ee[0].real))
        for i in range(0,5):
            print('{:0.4f} eV'.format(-ee[i].real))
        m=5
        plt.plot(range(0,m), ee[:m].real)
        plt.xlabel(r'$n$)', fontsize=20)
        plt.ylabel(r'$-E_b(n)$', fontsize=20)
        plt.title('Lowest exciton eigenenergies',fontsize=20)
        plt.savefig('./plots/binding_energies_vdWH_{}_{}_{}.svg'.format(e_layer_formula[2:],h_layer_formula[2:],nPadding))
        plt.show()
        #save binding energy
        binding_Energies_Mat[ie,jh]=-ee[0].real
bindEnVec=binding_Energies_Mat.reshape(n_material**2,1)
print(binding_Energies_Mat)
# Out:
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27315855e+05 -1.46717956e+03 -5.05234776e+02 -2.32079011e+02
#  -5.40636033e+01 -1.97894324e+01 -8.95796949e+00 -4.50493082e+00
#  -2.42209951e+00 -1.36502112e+00 -7.91232704e-01 -4.64416398e-01
#  -2.72483979e-01 -1.57616463e-01 -8.81554435e-02 -4.60661292e-02
#  -2.06928172e-02 -5.64712319e-03  2.94827729e-03  7.51883207e-03
#   9.61622260e-03  1.02268408e-02  9.97204220e-03  8.28966109e-03
#   6.24724333e-03  4.44235890e-03  3.02878721e-03  1.99122959e-03
#   1.26137928e-03  7.64368014e-04  4.35378489e-04  2.23698187e-04
#   9.18511564e-05  1.30741731e-05 -3.12427850e-05 -5.37501132e-05
#  -6.28830046e-05 -6.41490344e-05 -6.10657393e-05 -5.58258040e-05
#  -4.97531142e-05 -4.36147332e-05 -3.78263687e-05 -3.25866270e-05
#  -2.79654667e-05 -2.39592236e-05 -2.05250546e-05]
# The interlayer exciton binding energy is: 0.1616 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1616 eV
# 0.1043 eV
# 0.0745 eV
# 0.0565 eV
# 0.0449 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27226053e+05 -1.43963349e+03 -4.91284920e+02 -2.24093608e+02
#  -5.15736214e+01 -1.86844871e+01 -8.35039853e+00 -4.13893692e+00
#  -2.18598753e+00 -1.20286423e+00 -6.74601904e-01 -3.77829640e-01
#  -2.06630297e-01 -1.06585678e-01 -4.80548705e-02 -1.42336733e-02
#   4.73292546e-03  1.47271687e-02  1.93159282e-02  2.06984061e-02
#   2.02399730e-02  1.87892307e-02  1.68720425e-02  1.27708747e-02
#   9.15344938e-03  6.32101670e-03  4.23729777e-03  2.76352209e-03
#   1.75064301e-03  1.07081795e-03  6.24441524e-04  3.37963700e-04
#   1.58921912e-04  5.07427974e-05 -1.15803554e-05 -4.48552076e-05
#  -6.02050138e-05 -6.48714282e-05 -6.34835201e-05 -5.89379784e-05
#  -5.29988806e-05 -4.67010280e-05 -4.06182248e-05 -3.50393792e-05
#  -3.00831864e-05 -2.57702985e-05 -2.20679198e-05]
# The interlayer exciton binding energy is: 0.1565 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1565 eV
# 0.1015 eV
# 0.0727 eV
# 0.0554 eV
# 0.0442 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27874885e+05 -1.38696338e+03 -4.65072593e+02 -2.09342590e+02
#  -4.71599676e+01 -1.67660726e+01 -7.34163218e+00 -3.55697773e+00
#  -1.82251826e+00 -9.58973080e-01 -5.01930345e-01 -2.50716022e-01
#  -1.10334241e-01 -3.21169351e-02  1.03792460e-02  3.20900451e-02
#   4.17044513e-02  4.43600941e-02  4.31361494e-02  3.98879667e-02
#   3.57226871e-02  3.12917820e-02  2.69701372e-02  1.93529260e-02
#   1.34342747e-02  9.09640615e-03  6.02946889e-03  3.91511958e-03
#   2.48615858e-03  1.53699828e-03  9.16970987e-04  5.19094008e-04
#   2.69269035e-04  1.16807200e-04  2.73161402e-05 -2.22961362e-05
#  -4.74470839e-05 -5.81114121e-05 -6.04683157e-05 -5.82186679e-05
#  -5.35417387e-05 -4.77885911e-05 -4.18099226e-05 -3.61337275e-05
#  -3.10345120e-05 -2.65846000e-05 -2.27624866e-05]
# The interlayer exciton binding energy is: 0.1476 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1476 eV
# 0.0965 eV
# 0.0696 eV
# 0.0534 eV
# 0.0429 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27267459e+05 -1.48240221e+03 -5.13151446e+02 -2.36713421e+02
#  -5.58046126e+01 -2.06103615e+01 -9.38731528e+00 -4.75136547e+00
#  -2.57298429e+00 -1.46178281e+00 -8.55799326e-01 -5.09080963e-01
#  -3.04328537e-01 -1.80888526e-01 -1.05521721e-01 -5.92590715e-02
#  -3.08687976e-02 -1.35980960e-02 -3.33126471e-03  2.51551158e-03
#   5.59953642e-03  6.98069363e-03  7.33416125e-03  6.52594796e-03
#   5.05250914e-03  3.62472503e-03  2.46470298e-03  1.59962239e-03
#   9.88212805e-04  5.73144322e-04  3.01182015e-04  1.29375015e-04
#   2.55037709e-05 -3.35928072e-05 -6.40357613e-05 -7.67470597e-05
#  -7.89533170e-05 -7.53180044e-05 -6.87681209e-05 -6.10803460e-05
#  -5.32849602e-05 -4.59402304e-05 -3.93124981e-05 -3.34937451e-05
#  -2.84775517e-05 -2.42056058e-05 -2.05962505e-05]
# The interlayer exciton binding energy is: 0.1648 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1648 eV
# 0.1059 eV
# 0.0755 eV
# 0.0571 eV
# 0.0453 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27266578e+05 -1.45685596e+03 -5.00080202e+02 -2.29185940e+02
#  -5.34235324e+01 -1.95487007e+01 -8.80684067e+00 -4.40436525e+00
#  -2.35067019e+00 -1.30983738e+00 -7.46640631e-01 -4.27802645e-01
#  -2.42150418e-01 -1.32344725e-01 -6.70463867e-02 -2.84291890e-02
#  -6.00072686e-03  6.53156815e-03  1.30058311e-02  1.58052259e-02
#   1.64228305e-02  1.57964798e-02  1.45150282e-02  1.12915898e-02
#   8.21342989e-03  5.71812533e-03  3.84801860e-03  2.51101422e-03
#   1.58640442e-03  9.63884156e-04  5.54866621e-04  2.92810990e-04
#   1.29761375e-04  3.20558771e-05 -2.34185374e-05 -5.22302806e-05
#  -6.46881675e-05 -6.74960158e-05 -6.49270125e-05 -5.96422243e-05
#  -5.32497744e-05 -4.66821385e-05 -4.04463334e-05 -3.47878851e-05
#  -2.97974052e-05 -2.54774300e-05 -2.17836147e-05]
# The interlayer exciton binding energy is: 0.1600 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1600 eV
# 0.1033 eV
# 0.0738 eV
# 0.0561 eV
# 0.0446 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26965083e+05 -1.43932334e+03 -4.91238517e+02 -2.24097584e+02
#  -5.15843020e+01 -1.86930145e+01 -8.36290889e+00 -4.15649981e+00
#  -2.20745096e+00 -1.22634787e+00 -6.98504569e-01 -4.00988732e-01
#  -2.28265164e-01 -1.26255601e-01 -6.55852924e-02 -2.96208528e-02
#  -8.59989550e-03  3.30379334e-03  9.61526554e-03  1.25167886e-02
#   1.33821515e-02  1.30751221e-02  1.21346882e-02  9.55241574e-03
#   6.99574706e-03  4.89175440e-03  3.30156321e-03  2.15829313e-03
#   1.36438030e-03  8.28104766e-04  4.74798429e-04  2.47918053e-04
#   1.06497269e-04  2.16603175e-05 -2.64978237e-05 -5.14318916e-05
#  -6.20840200e-05 -6.42846430e-05 -6.17587726e-05 -5.68332597e-05
#  -5.09191904e-05 -4.48400789e-05 -3.90482761e-05 -3.37663038e-05
#  -2.90797471e-05 -2.49953203e-05 -2.14771337e-05]
# The interlayer exciton binding energy is: 0.1565 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1565 eV
# 0.1015 eV
# 0.0727 eV
# 0.0554 eV
# 0.0442 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26842280e+05 -1.41301786e+03 -4.78240410e+02 -2.16799722e+02
#  -4.94344648e+01 -1.78100776e+01 -7.91761540e+00 -3.91306126e+00
#  -2.06508568e+00 -1.13643796e+00 -6.37824048e-01 -3.57879200e-01
#  -1.96302627e-01 -1.01721461e-01 -4.62537858e-02 -1.41045266e-02
#   3.98239738e-03  1.35498933e-02  1.79825868e-02  1.93672957e-02
#   1.89923893e-02  1.76615549e-02  1.58783148e-02  1.20392703e-02
#   8.63868200e-03  5.96914988e-03  4.00176362e-03  2.60847908e-03
#   1.65005982e-03  1.00644345e-03  5.83777397e-04  3.12603315e-04
#   1.43295585e-04  4.12134740e-05 -1.73542035e-05 -4.83593554e-05
#  -6.23682658e-05 -6.62647713e-05 -6.44510401e-05 -5.96816900e-05
#  -5.36332743e-05 -4.72871508e-05 -4.11852508e-05 -3.55982179e-05
#  -3.06348331e-05 -2.63110420e-05 -2.25924372e-05]
# The interlayer exciton binding energy is: 0.1522 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1522 eV
# 0.0990 eV
# 0.0712 eV
# 0.0544 eV
# 0.0435 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27384159e+05 -1.36187950e+03 -4.53079912e+02 -2.02699490e+02
#  -4.51858364e+01 -1.59439188e+01 -6.92793356e+00 -3.33625630e+00
#  -1.70084920e+00 -8.89705032e-01 -4.61854829e-01 -2.27646954e-01
#  -9.73076075e-02 -2.50329771e-02  1.39487848e-02  3.35987853e-02
#   4.20148843e-02  4.39896665e-02  4.24098438e-02  3.90085167e-02
#   3.48072113e-02  3.04049961e-02  2.61481972e-02  1.87022646e-02
#   1.29506327e-02  8.74960855e-03  5.78643556e-03  3.74747453e-03
#   2.37171465e-03  1.45926623e-03  8.64117786e-04  4.82858526e-04
#   2.44205053e-04  9.94691347e-05  1.55200769e-05 -2.99708888e-05
#  -5.21229207e-05 -6.07748128e-05 -6.19266259e-05 -5.90862977e-05
#  -5.41938460e-05 -4.83880561e-05 -4.24032290e-05 -3.67136661e-05
#  -3.15858241e-05 -2.71024982e-05 -2.32477453e-05]
# The interlayer exciton binding energy is: 0.1436 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1436 eV
# 0.0942 eV
# 0.0682 eV
# 0.0525 eV
# 0.0422 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26902959e+05 -1.45373418e+03 -4.98513565e+02 -2.28258599e+02
#  -5.30943019e+01 -1.93827508e+01 -8.71008132e+00 -4.34900151e+00
#  -2.32170275e+00 -1.29739959e+00 -7.44504695e-01 -4.31918384e-01
#  -2.49730629e-01 -1.41538475e-01 -7.67045094e-02 -3.78638027e-02
#  -1.48116107e-02 -1.44535705e-03  5.94028089e-03  9.64512306e-03
#   1.11186627e-02  1.12765210e-02  1.06958937e-02  8.61805566e-03
#   6.37923371e-03  4.47950761e-03  3.02276532e-03  1.96792086e-03
#   1.23334388e-03  7.37308584e-04  4.11532100e-04  2.03625165e-04
#   7.53615196e-05 -3.00766699e-07 -4.20276229e-05 -6.24312226e-05
#  -6.98743116e-05 -6.97908437e-05 -6.56340173e-05 -5.95417167e-05
#  -5.27930960e-05 -4.61180812e-05 -3.99018416e-05 -3.43188338e-05
#  -2.94199127e-05 -2.51866553e-05 -2.15651781e-05]
# The interlayer exciton binding energy is: 0.1593 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1593 eV
# 0.1030 eV
# 0.0736 eV
# 0.0559 eV
# 0.0445 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26880991e+05 -1.42924012e+03 -4.86238725e+02 -2.21288721e+02
#  -5.09399493e+01 -1.84426779e+01 -8.20690444e+00 -4.05393780e+00
#  -2.13566618e+00 -1.17174634e+00 -6.54947834e-01 -3.65568040e-01
#  -1.99126078e-01 -1.02100709e-01 -4.54791327e-02 -1.28611485e-02
#   5.33838023e-03  1.48425731e-02  1.91344270e-02  2.03533244e-02
#   1.98147899e-02  1.83350322e-02  1.64219353e-02  1.23812973e-02
#   8.84568292e-03  6.08980943e-03  4.06903402e-03  2.64370400e-03
#   1.66663996e-03  1.01258773e-03  5.84394997e-04  3.10553358e-04
#   1.40193661e-04  3.79264419e-05 -2.03998439e-05 -5.09872880e-05
#  -6.45380384e-05 -6.80032212e-05 -6.58133320e-05 -6.07302456e-05
#  -5.44271031e-05 -4.78780360e-05 -4.16168324e-05 -3.59063574e-05
#  -3.08484660e-05 -2.64531202e-05 -2.26809402e-05]
# The interlayer exciton binding energy is: 0.1550 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1550 eV
# 0.1005 eV
# 0.0721 eV
# 0.0550 eV
# 0.0439 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26751406e+05 -1.38509569e+03 -4.64618316e+02 -2.09247565e+02
#  -4.72620192e+01 -1.68962967e+01 -7.47817568e+00 -3.69333797e+00
#  -1.95442418e+00 -1.08250241e+00 -6.14518610e-01 -3.51265467e-01
#  -1.98699497e-01 -1.08745930e-01 -5.53607388e-02 -2.38258363e-02
#  -5.50907006e-03  4.75072074e-03  1.00822594e-02  1.24210388e-02
#   1.29831265e-02  1.25315901e-02  1.15414710e-02  9.00125783e-03
#   6.55441958e-03  4.56359779e-03  3.06846096e-03  1.99805730e-03
#   1.25733634e-03  7.58811493e-04  4.31835496e-04  2.23089831e-04
#   9.36750132e-05  1.61686130e-05 -2.80989907e-05 -5.15393868e-05
#  -6.19575363e-05 -6.42689766e-05 -6.17424435e-05 -5.65475300e-05
#  -5.02177597e-05 -4.37718247e-05 -3.77496792e-05 -3.23880631e-05
#  -2.77297092e-05 -2.37250011e-05 -2.03057373e-05]
# The interlayer exciton binding energy is: 0.1477 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1477 eV
# 0.0964 eV
# 0.0696 eV
# 0.0533 eV
# 0.0428 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26760144e+05 -1.36045931e+03 -4.52531218e+02 -2.02418008e+02
#  -4.50965414e+01 -1.59166786e+01 -6.93468905e+00 -3.36304191e+00
#  -1.73939719e+00 -9.33760175e-01 -5.06921591e-01 -2.70988631e-01
#  -1.37391041e-01 -6.10758307e-02 -1.77916825e-02  6.07870839e-03
#   1.84433006e-02  2.40009675e-02  2.55963161e-02  2.49574736e-02
#   2.31283657e-02  2.07443193e-02  1.81921947e-02  1.33707088e-02
#   9.42871144e-03  6.45420691e-03  4.31071482e-03  2.81272178e-03
#   1.79011559e-03  1.10597943e-03  6.57009161e-04  3.68276215e-04
#   1.86526673e-04  7.48491395e-05  8.34618581e-06 -2.94731702e-05
#  -4.90677991e-05 -5.71215660e-05 -5.81091698e-05 -5.50208550e-05
#  -4.99362334e-05 -4.42126224e-05 -3.85922226e-05 -3.34302342e-05
#  -2.88434041e-05 -2.48348248e-05 -2.13711788e-05]
# The interlayer exciton binding energy is: 0.1434 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1434 eV
# 0.0941 eV
# 0.0681 eV
# 0.0524 eV
# 0.0422 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27298492e+05 -1.31291293e+03 -4.29730337e+02 -1.89798422e+02
#  -4.13008360e+01 -1.42444756e+01 -6.04386619e+00 -2.83940065e+00
#  -1.40518095e+00 -7.05055835e-01 -3.42430289e-01 -1.48457720e-01
#  -4.38135188e-02  1.16406155e-02  3.93986008e-02  5.14387925e-02
#   5.46204000e-02  5.29538564e-02  4.88222440e-02  4.36228517e-02
#   3.81479040e-02  3.28384541e-02  2.79314706e-02  1.96789674e-02
#   1.35033549e-02  9.07572787e-03  5.98861756e-03  3.87957812e-03
#   2.46253062e-03  1.52460000e-03  9.12888438e-04  5.20213902e-04
#   2.73001066e-04  1.21399902e-04  3.19146064e-05 -1.78122001e-05
#  -4.29448667e-05 -5.35932617e-05 -5.60884688e-05 -5.42027055e-05
#  -5.00717999e-05 -4.49549866e-05 -3.96196009e-05 -3.44895512e-05
#  -2.97834466e-05 -2.56057543e-05 -2.19781162e-05]
# The interlayer exciton binding energy is: 0.1358 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1358 eV
# 0.0898 eV
# 0.0655 eV
# 0.0507 eV
# 0.0411 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26825323e+05 -1.39870493e+03 -4.71237759e+02 -2.12957170e+02
#  -4.85799224e+01 -1.74831020e+01 -7.76324938e+00 -3.84575955e+00
#  -2.04178925e+00 -1.13501679e+00 -6.47435814e-01 -3.72762783e-01
#  -2.13235579e-01 -1.18851095e-01 -6.25483333e-02 -2.90372708e-02
#  -9.35057012e-03  1.87771475e-03  7.90903900e-03  1.07639297e-02
#   1.17110921e-02  1.15489330e-02  1.07789427e-02  8.53991947e-03
#   6.27542919e-03  4.39599457e-03  2.96915753e-03  1.94061039e-03
#   1.22541308e-03  7.42262215e-04  4.24340093e-04  2.20728634e-04
#   9.40539619e-05  1.78640302e-05 -2.59023186e-05 -4.92807638e-05
#  -5.98567741e-05 -6.24271362e-05 -6.01965573e-05 -5.53014589e-05
#  -4.92539287e-05 -4.30567050e-05 -3.72421477e-05 -3.20447792e-05
#  -2.75103410e-05 -2.35962351e-05 -2.02412571e-05]
# The interlayer exciton binding energy is: 0.1501 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1501 eV
# 0.0977 eV
# 0.0704 eV
# 0.0539 eV
# 0.0431 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26900891e+05 -1.37620073e+03 -4.60282658e+02 -2.06841863e+02
#  -4.67161418e+01 -1.66788506e+01 -7.33625987e+00 -3.59548993e+00
#  -1.88289398e+00 -1.02642087e+00 -5.68931865e-01 -3.13747363e-01
#  -1.67609938e-01 -8.28695614e-02 -3.37740196e-02 -5.80691398e-03
#   9.49797720e-03  1.71987130e-02  2.03774187e-02  2.09224425e-02
#   1.99881724e-02  1.82867306e-02  1.62589110e-02  1.21578265e-02
#   8.65639758e-03  5.95675817e-03  3.98749394e-03  2.60134847e-03
#   1.65125170e-03  1.01446890e-03  5.96587059e-04  3.28338155e-04
#   1.60141837e-04  5.74773612e-05 -2.99628910e-06 -3.67524136e-05
#  -5.36070834e-05 -5.98344560e-05 -5.96317592e-05 -5.57986465e-05
#  -5.02685884e-05 -4.42867135e-05 -3.85204406e-05 -3.32761139e-05
#  -2.86431640e-05 -2.46120189e-05 -2.11415700e-05]
# The interlayer exciton binding energy is: 0.1464 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1464 eV
# 0.0956 eV
# 0.0690 eV
# 0.0530 eV
# 0.0426 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27172559e+05 -1.48215991e+03 -5.13069431e+02 -2.36656957e+02
#  -5.57178214e+01 -2.05108775e+01 -9.29574461e+00 -4.67293352e+00
#  -2.50813265e+00 -1.40925642e+00 -8.13680848e-01 -4.75450712e-01
#  -2.77525614e-01 -1.59543226e-01 -8.85244997e-02 -4.57204570e-02
#  -2.00761738e-02 -4.98325296e-03  3.55397299e-03  8.02398968e-03
#   1.00114685e-02  1.05191819e-02  1.01757889e-02  8.36418922e-03
#   6.24608941e-03  4.40235420e-03  2.97283791e-03  1.93247925e-03
#   1.20668568e-03  7.16772884e-04  3.95743856e-04  1.91729901e-04
#   6.67027687e-05 -6.29801847e-06 -4.58840793e-05 -6.46117132e-05
#  -7.07811708e-05 -6.97597056e-05 -6.49358183e-05 -5.83900558e-05
#  -5.13529767e-05 -4.45150145e-05 -3.82296686e-05 -3.26459679e-05
#  -2.77948207e-05 -2.36422737e-05 -2.01223798e-05]
# The interlayer exciton binding energy is: 0.1646 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1646 eV
# 0.1059 eV
# 0.0754 eV
# 0.0571 eV
# 0.0453 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27181488e+05 -1.45419397e+03 -4.98695365e+02 -2.28350822e+02
#  -5.30814674e+01 -1.93333991e+01 -8.64980991e+00 -4.28655107e+00
#  -2.26148144e+00 -1.24189299e+00 -6.94701763e-01 -3.88027125e-01
#  -2.11591924e-01 -1.08769764e-01 -4.87946606e-02 -1.42589288e-02
#   5.02812454e-03  1.51353905e-02  1.97333850e-02  2.10773653e-02
#   2.05617421e-02  1.90504663e-02  1.70776763e-02  1.28903116e-02
#   9.21747067e-03  6.35206824e-03  4.25007038e-03  2.76700024e-03
#   1.75000098e-03  1.06884870e-03  6.22522957e-04  3.36671977e-04
#   1.58399316e-04  5.09216783e-05 -1.08506156e-05 -4.37413133e-05
#  -5.88545869e-05 -6.34022006e-05 -6.19836816e-05 -5.74699513e-05
#  -5.16049332e-05 -4.54075768e-05 -3.94392972e-05 -3.39798423e-05
#  -2.91413362e-05 -2.49400940e-05 -2.13408520e-05]
# The interlayer exciton binding energy is: 0.1593 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1593 eV
# 0.1030 eV
# 0.0736 eV
# 0.0560 eV
# 0.0446 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27720787e+05 -1.40017258e+03 -4.71599448e+02 -2.13015813e+02
#  -4.84272693e+01 -1.72886750e+01 -7.56661554e+00 -3.65853099e+00
#  -1.86877972e+00 -9.79071262e-01 -5.09571803e-01 -2.52615224e-01
#  -1.09722837e-01 -3.05371204e-02  1.21910030e-02  3.37962602e-02
#   4.31705426e-02  4.55527724e-02  4.40706145e-02  4.05986501e-02
#   3.62479261e-02  3.16679238e-02  2.72297886e-02  1.94573450e-02
#   1.34547747e-02  9.07573513e-03  5.99208153e-03  3.87424299e-03
#   2.44816946e-03  1.50435311e-03  8.90094765e-04  4.97489877e-04
#   2.52348501e-04  1.04109744e-04  1.84289229e-05 -2.77957225e-05
#  -5.01898390e-05 -5.88943741e-05 -6.00561339e-05 -5.72430577e-05
#  -5.24036673e-05 -4.66687483e-05 -4.07675454e-05 -3.51703079e-05
#  -3.01409963e-05 -2.57608854e-05 -2.20116334e-05]
# The interlayer exciton binding energy is: 0.1498 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1498 eV
# 0.0977 eV
# 0.0704 eV
# 0.0539 eV
# 0.0432 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27247509e+05 -1.49770768e+03 -5.21038233e+02 -2.41251542e+02
#  -5.73843396e+01 -2.12641105e+01 -9.66920453e+00 -4.87580131e+00
#  -2.62540764e+00 -1.47994022e+00 -8.57866855e-01 -5.04070370e-01
#  -2.96636152e-01 -1.72628984e-01 -9.76820470e-02 -5.22526985e-02
#  -2.48148432e-02 -8.47273447e-03  9.52384456e-04  6.06591321e-03
#   8.52578298e-03  9.38343240e-03  9.30270862e-03  7.84427381e-03
#   5.93567262e-03  4.21786863e-03  2.86458276e-03  1.87044729e-03
#   1.17258949e-03  6.99375768e-04  3.88115782e-04  1.89608936e-04
#   6.74961860e-05 -4.13480566e-06 -4.32419361e-05 -6.19786624e-05
#  -6.83987553e-05 -6.77261768e-05 -6.32706668e-05 -5.70715081e-05
#  -5.03404804e-05 -4.37614140e-05 -3.76877145e-05 -3.22721041e-05
#  -2.75507088e-05 -2.34952921e-05 -2.00457047e-05]
# The interlayer exciton binding energy is: 0.1677 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1677 eV
# 0.1075 eV
# 0.0764 eV
# 0.0577 eV
# 0.0458 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27222085e+05 -1.47186155e+03 -5.07827658e+02 -2.33678717e+02
#  -5.50389627e+01 -2.02489840e+01 -9.13023166e+00 -4.56293341e+00
#  -2.43061752e+00 -1.35002259e+00 -7.66301693e-01 -4.36867948e-01
#  -2.45748789e-01 -1.33164644e-01 -6.65280775e-02 -2.73444931e-02
#  -4.75252259e-03  7.74349673e-03  1.40927653e-02  1.67369500e-02
#   1.71980619e-02  1.64278952e-02  1.50216675e-02  1.16082527e-02
#   8.40555963e-03  5.83186062e-03  3.91387100e-03  2.54839097e-03
#   1.60729140e-03  9.75497948e-04  5.61444911e-04  2.96773308e-04
#   1.32436500e-04  3.41377203e-05 -2.15934931e-05 -5.05185583e-05
#  -6.30413036e-05 -6.59087525e-05 -6.34111057e-05 -5.82131384e-05
#  -5.19212677e-05 -4.54637042e-05 -3.93423366e-05 -3.37980343e-05
#  -2.89176155e-05 -2.47009293e-05 -2.11020874e-05]
# The interlayer exciton binding energy is: 0.1629 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1629 eV
# 0.1048 eV
# 0.0748 eV
# 0.0567 eV
# 0.0450 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26880921e+05 -1.45625493e+03 -4.99935037e+02 -2.29131126e+02
#  -5.33768068e+01 -1.94995189e+01 -8.76921958e+00 -4.38075146e+00
#  -2.33926251e+00 -1.30751247e+00 -7.50444361e-01 -4.35368293e-01
#  -2.51709946e-01 -1.42671971e-01 -7.73523928e-02 -3.82334310e-02
#  -1.50215664e-02 -1.56305184e-03  5.87307228e-03  9.60216501e-03
#   1.10868312e-02  1.12504262e-02  1.06721003e-02  8.59291813e-03
#   6.35254635e-03  4.45375636e-03  2.99992738e-03  1.94895757e-03
#   1.21841421e-03  7.26125529e-04  4.03610651e-04  1.98420593e-04
#   7.23377845e-05 -1.63566141e-06 -4.21022748e-05 -6.16035337e-05
#  -6.84338976e-05 -6.79634309e-05 -6.35890975e-05 -5.74031863e-05
#  -5.06489117e-05 -4.40288924e-05 -3.79081096e-05 -3.24459000e-05
#  -2.76821362e-05 -2.35905154e-05 -2.01113837e-05]
# The interlayer exciton binding energy is: 0.1598 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1598 eV
# 0.1032 eV
# 0.0738 eV
# 0.0560 eV
# 0.0446 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26889676e+05 -1.42910586e+03 -4.86111005e+02 -2.21167237e+02
#  -5.08236383e+01 -1.83417098e+01 -8.12547101e+00 -3.98974392e+00
#  -2.08548660e+00 -1.13262353e+00 -6.24386512e-01 -3.41596912e-01
#  -1.80235140e-01 -8.71422690e-02 -3.35799665e-02 -3.35436849e-03
#   1.29652668e-02  2.09853556e-02  2.41001052e-02  2.43810931e-02
#   2.30919995e-02  2.10093724e-02  1.86105599e-02  1.38591136e-02
#   9.85342996e-03  6.78304964e-03  4.54965226e-03  2.97925297e-03
#   1.90243421e-03  1.17931133e-03  7.02993289e-04  3.95425322e-04
#   2.01295386e-04  8.21834730e-05  1.18571086e-05 -2.73230308e-05
#  -4.70545328e-05 -5.49855593e-05 -5.60378933e-05 -5.33212384e-05
#  -4.87563422e-05 -4.34930417e-05 -3.81899821e-05 -3.31990553e-05
#  -2.86858452e-05 -2.47063045e-05 -2.12543991e-05]
# The interlayer exciton binding energy is: 0.1547 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1547 eV
# 0.1004 eV
# 0.0721 eV
# 0.0550 eV
# 0.0439 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27525758e+05 -1.37709635e+03 -4.60350318e+02 -2.06700408e+02
#  -4.64701407e+01 -1.64424142e+01 -7.12811955e+00 -3.41586358e+00
#  -1.72864031e+00 -8.94764736e-01 -4.57342325e-01 -2.19692199e-01
#  -8.87097769e-02 -1.69961366e-02  2.09783821e-02  3.95262441e-02
#   4.69019305e-02  4.79601485e-02  4.56036454e-02  4.15595289e-02
#   3.68344329e-02  3.20098452e-02  2.74147801e-02  1.94854647e-02
#   1.34314508e-02  9.04325973e-03  5.96517248e-03  3.85616675e-03
#   2.43794841e-03  1.49986532e-03  8.89282269e-04  4.98742231e-04
#   2.54582915e-04  1.06687653e-04  2.10224599e-05 -2.53171691e-05
#  -4.78830701e-05 -5.68060215e-05 -5.82284478e-05 -5.57140541e-05
#  -5.11839602e-05 -4.57315570e-05 -4.00656245e-05 -3.46489096e-05
#  -2.97514422e-05 -2.54676921e-05 -2.17895692e-05]
# The interlayer exciton binding energy is: 0.1459 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1459 eV
# 0.0955 eV
# 0.0690 eV
# 0.0530 eV
# 0.0426 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.26951256e+05 -1.47125795e+03 -5.07519542e+02 -2.33470564e+02
#  -5.49434258e+01 -2.02054411e+01 -9.11698957e+00 -4.56861587e+00
#  -2.44745936e+00 -1.37255956e+00 -7.91052957e-01 -4.61676532e-01
#  -2.69302746e-01 -1.54745563e-01 -8.58242330e-02 -4.42936552e-02
#  -1.94309299e-02 -4.82033157e-03  3.43699238e-03  7.76340039e-03
#   9.68801115e-03  1.01784623e-02  9.84623086e-03  8.09938813e-03
#   6.05719435e-03  4.27801693e-03  2.89681611e-03  1.88998036e-03
#   1.18614316e-03  7.09822884e-04  3.96640974e-04  1.96697830e-04
#   7.33749890e-05  6.80567695e-07 -3.93598699e-05 -5.89005656e-05
#  -6.59989727e-05 -6.58874581e-05 -6.18874623e-05 -5.60518600e-05
#  -4.96061358e-05 -4.32469219e-05 -3.73394526e-05 -3.20469417e-05
#  -2.74145529e-05 -2.34217042e-05 -2.00145140e-05]
# The interlayer exciton binding energy is: 0.1627 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1627 eV
# 0.1048 eV
# 0.0747 eV
# 0.0567 eV
# 0.0450 eV
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# Calculating full chi
# 10.0%
# 20.0%
# 30.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 90.0%
# [-6.27029115e+05 -1.44645711e+03 -4.94980477e+02 -2.26329735e+02
#  -5.27389438e+01 -1.92514996e+01 -8.61121866e+00 -4.27476238e+00
#  -2.26383466e+00 -1.24945777e+00 -7.03790489e-01 -3.97254670e-01
#  -2.20259327e-01 -1.16541371e-01 -5.55587082e-02 -2.00306922e-02
#   1.52045790e-04  1.10341069e-02  1.63002906e-02  1.82193220e-02
#   1.81917341e-02  1.70901327e-02  1.54601186e-02  1.17969833e-02
#   8.48499981e-03  5.86545230e-03  3.92951848e-03  2.55773260e-03
#   1.61473270e-03  9.82408257e-04  5.68035842e-04  3.02905658e-04
#   1.37939777e-04  3.89097095e-05 -1.75762346e-05 -4.72193749e-05
#  -6.03889125e-05 -6.38166459e-05 -6.17900741e-05 -5.69789621e-05
#  -5.09984073e-05 -4.47865930e-05 -3.88557478e-05 -3.34565374e-05
#  -2.86845939e-05 -2.45474577e-05 -2.10056706e-05]
# The interlayer exciton binding energy is: 0.1583 eV
# The (first 5) interlayer exciton binding energies are:
# 0.1583 eV
# 0.1023 eV
# 0.0732 eV
# 0.0557 eV
# 0.0444 eV
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-058a8acc40bb> in <module>
#     123         #save binding energy
#     124         binding_Energies_Mat[ie,jh]=-ee[0].real
# --> 125 bindEnVec=binding_Energies_Mat.reshape(n_material**2,1)
#     126 print(binding_Energies_Mat)
#
# NameError: name 'n_material' is not defined

# %%
#print(binding_Energies_Mat)
#print(binding_Energies_Mat.reshape(25,1))
n_material=5
bindEnVec=binding_Energies_Mat.reshape(n_material**2,1)
#print(binding_Energies_Mat.max())
#print(binding_Energies_Mat[binding_Energies_Mat>0].min())
#print(bindEnVec==binding_Energies_Mat.max())
TruthVecMax=bindEnVec==binding_Energies_Mat.max()
TruthVecMax=TruthVecMax.reshape(n_material**2,1)
max_ind=np.arange(25)[TruthVecMax.flatten()][0]
max_index=index_Vec[max_ind]
print('Maximum binding energy: {} for e_layer: {} and h_layer {}'.format(binding_Energies_Mat.max(),material_List[max_index[0]],material_List[max_index[1]]))

TruthVecMin=bindEnVec==binding_Energies_Mat[binding_Energies_Mat>0].min()
TruthVecMin=TruthVecMin.reshape(n_material**2,1)
min_ind=np.arange(25)[TruthVecMin.flatten()][0]
min_index=index_Vec[min_ind]
print('Minimum binding energy: {} for e_layer: {} and h_layer {}'.format(binding_Energies_Mat[binding_Energies_Mat>0].min(),material_List[min_index[0]],material_List[min_index[1]]))

print(material_List)
print(binding_Energies_Mat)
# Out:
# Maximum binding energy: 0.16765012239745677 for e_layer: H-WS2 and h_layer H-WS2
# Minimum binding energy: 0.13578421642909458 for e_layer: H-MoTe2 and h_layer H-MoTe2
# ['H-MoS2', 'H-MoSe2', 'H-MoTe2', 'H-WS2', 'H-WSe2']
# [[0.16158975 0.15652825 0.14755881 0.16479475 0.159979  ]
#  [0.15654227 0.1521594  0.1435646  0.15932561 0.15496412]
#  [0.14769934 0.14340047 0.13578422 0.15012196 0.14635821]
#  [0.1645547  0.15925073 0.14981929 0.16765012 0.16288091]
#  [0.15984849 0.15474145 0.14594285 0.16274767 0.15828345]]

# %%
material_List=['H-MoS2','H-MoSe2','H-MoTe2','H-WS2','H-WSe2']
n_materials=len(material_List)
range_materials=range(n_materials)
index_Vec=[(ie,jh) for ie in range_materials for jh in range_materials]
print(index_Vec)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4), (3, 0), (3, 1), (3, 2), (3, 3), (3, 4), (4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]

# %%
emptyList=[[]]*4
emptyList[0]=np.array([2,3,4])
print(emptyList)
# Out:
# [array([2, 3, 4]), [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
#print(W_Exciton_Matrix)
a=np.array(W_Exciton_Matrix[1])
#print(W_Exciton_Matrix[1])
np.shape(a)
len(a[1:])
print(index_Vec[1][0])
# Out:
# 0

# %%
indexQ_start=4
q_reduced=q[indexQ_start:]
W_nonempty=np.zeros(len(q_reduced)).reshape(1,len(q_reduced))
for i in range(n_materials**2):
    W_Exciton=np.array(W_Exciton_Matrix[i])
    plt.plot(q_reduced, W_Exciton[indexQ_start:].real)
    plt.xlabel(r'$q_\parallel (\mathrm{\AA^{-1}}$)', fontsize=20)
    plt.ylabel(r'$W(q, \omega=0)$', fontsize=20)
    W_nonempty=np.row_stack((W_nonempty,W_Exciton[indexQ_start:].real))
W_nonempty=W_nonempty[1:]
plt.xlim(0,0.2)
plt.title("Screened exciton potential for all combinations")
plt.savefig('./plots/VScr_Exciton_vdWH_all_combinations_{}.svg'.format(nPadding))
plt.show()

# %%
# Out:
# (1, 20)

# %%
#Nu laver jeg noget, der måske er lidt fjollet, men jeg undersøger, hvad forskellen er mellem de forskellige materiale
#ved til hver q-værdi at finde den hhv. største og mindste potential-værdi og plotte den
W_min=np.min(W_nonempty,axis=0)#take coloum-wise minimum
W_max=np.max(W_nonempty,axis=0)#take coloum-wise minimum
#plot
plt.plot(q_reduced, W_min)
plt.plot(q_reduced, W_max)
plt.xlabel(r'$q_\parallel (\mathrm{\AA^{-1}}$)', fontsize=20)
plt.ylabel(r'$W(q, \omega=0)$', fontsize=20)
plt.legend(['min','max'], fontsize=20)
plt.xlim(0,0.2)
plt.title('Variation Screened exciton potential between materials', fontsize=20)
plt.savefig('./plots/VScr_Exciton_vdWH_min_and_max_Padding{}.svg'.format(nPadding))
